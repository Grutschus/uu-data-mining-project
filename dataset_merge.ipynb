# %% [markdown]
# # Dataset Merge
# As a first step, we load the two datasets into memory and join them. Additionally we drop some attributes and rows to reduce the overall size of the dataset to a manageable size.

# %%
import pandas as pd
import dask.dataframe as dd
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Load Datasets
#
# ### Loading and cleaning the arXiv dataset

# %% [markdown]
# #### Loading from parquet

# %%
arxiv_raw = dd.read_parquet('dataset/arxiv_raw.parquet')
arxiv_raw.head()
# Out:
#                                                                      authors  \
# doi
# 0.1007/s00410-013-0898-x                     Denton S. Ebel, Richard O. Sack
# 0.1007/s10035-020-01057-3  Patrick Richard, Riccardo Artoni, Alexandre Va...
# 0.1007/s10092-022-00484-3  Rima Khouja (AROMATH), Bernard Mourrain (AROMA...
# 0.1007/s10652-005-0611-3   Victor S. L'vov, Anna Pomyalov, Vasil Tiberkevich
# 0.1007/s10659-021-09853-5         Boris Kolev (LMT), Rodrigue Desmorat (LMT)
#
#                                                                        title  \
# doi
# 0.1007/s00410-013-0898-x   Djerfisherite: Nebular Source of Refractory Po...
# 0.1007/s10035-020-01057-3  Influence of lateral confinement on granular f...
# 0.1007/s10092-022-00484-3  Newton-Type Methods For Simultaneous Matrix Di...
# 0.1007/s10652-005-0611-3   Simple analytical model for entire turbulent b...
# 0.1007/s10659-021-09853-5  An intrinsic geometric formulation of Hyper-el...
#
#                                                                     comments  \
# doi
# 0.1007/s00410-013-0898-x                       18 pages, 5 figures, 4 tables
# 0.1007/s10035-020-01057-3                                               <NA>
# 0.1007/s10092-022-00484-3                     Calcolo, Springer Verlag, 2022
# 0.1007/s10652-005-0611-3   14 pages, 5 figures, included, Enviromental fl...
# 0.1007/s10659-021-09853-5                                               <NA>
#
#                                                                  journal-ref  \
# doi
# 0.1007/s00410-013-0898-x   Contributions to Mineralogy and Petrology 166:...
# 0.1007/s10035-020-01057-3     Granular Matter, Springer Verlag, 2020, 22 (4)
# 0.1007/s10092-022-00484-3                                               <NA>
# 0.1007/s10652-005-0611-3   Environmental Fluid Mechanics, v. 5, 373-386 (...
# 0.1007/s10659-021-09853-5             Journal of Elasticity, Springer Verlag
#
#                                                        categories  \
# doi
# 0.1007/s00410-013-0898-x   astro-ph.EP astro-ph.IM physics.geo-ph
# 0.1007/s10035-020-01057-3                           cond-mat.soft
# 0.1007/s10092-022-00484-3                           math.NA cs.NA
# 0.1007/s10652-005-0611-3                                  nlin.CD
# 0.1007/s10659-021-09853-5                        physics.class-ph
#
#                                                                     abstract  \
# doi
# 0.1007/s00410-013-0898-x     Djerfisherite is an important carrier of pot...
# 0.1007/s10035-020-01057-3    The properties of confined granular flows ar...
# 0.1007/s10092-022-00484-3    This paper proposes a Newton-type method to ...
# 0.1007/s10652-005-0611-3     We discuss a simple analytical model of the ...
# 0.1007/s10659-021-09853-5    Isotropic hyper-elasticity, altogether with ...
#
#                           update_date  \
# doi
# 0.1007/s00410-013-0898-x   2023-08-08
# 0.1007/s10035-020-01057-3  2020-09-28
# 0.1007/s10092-022-00484-3  2022-11-07
# 0.1007/s10652-005-0611-3   2007-05-23
# 0.1007/s10659-021-09853-5  2021-08-31
#
#                                                               authors_parsed
# doi
# 0.1007/s00410-013-0898-x   [['Ebel', 'Denton S.', ''], ['Sack', 'Richard ...
# 0.1007/s10035-020-01057-3  [['Richard', 'Patrick', '', 'IPR'], ['Artoni',...
# 0.1007/s10092-022-00484-3  [['Khouja', 'Rima', '', 'AROMATH'], ['Mourrain...
# 0.1007/s10652-005-0611-3   [["L'vov", 'Victor S.', ''], ['Pomyalov', 'Ann...
# 0.1007/s10659-021-09853-5  [['Kolev', 'Boris', '', 'LMT'], ['Desmorat', '...

# %% [markdown]
# #### Reloading from scratch

# %%
ARXIV_RAW_PATH = Path("dataset/arxiv-metadata-oai-snapshot.json")
arxiv_raw = dd.read_json(
    ARXIV_RAW_PATH,
    lines=True,
    blocksize=1e6,
    dtype={"id": "str", "license": "str"},
)
display(arxiv_raw.head())
display(arxiv_raw.describe())
# Out:
#           id           submitter  \
# 0  0704.0001      Pavel Nadolsky
# 1  0704.0002        Louis Theran
# 2  0704.0003         Hongjun Pan
# 3  0704.0004        David Callan
# 4  0704.0005  Alberto Torchinsky
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                    Ileana Streinu and Louis Theran
# 2                                        Hongjun Pan
# 3                                       David Callan
# 4           Wael Abu-Shammala and Alberto Torchinsky
#
#                                                title  \
# 0  Calculation of prompt diphoton production cros...
# 1           Sparsity-certifying Graph Decompositions
# 2  The evolution of the Earth-Moon system based o...
# 3  A determinant of Stirling cycle numbers counts...
# 4  From dyadic $\Lambda_{\alpha}$ to $\Lambda_{\a...
#
#                                   comments  \
# 0  37 pages, 15 figures; published version
# 1    To appear in Graphs and Combinatorics
# 2                      23 pages, 3 figures
# 3                                 11 pages
# 4                                     <NA>
#
#                                  journal-ref                         doi  \
# 0                   Phys.Rev.D76:013009,2007  10.1103/PhysRevD.76.013009
# 1                                       <NA>                        <NA>
# 2                                       <NA>                        <NA>
# 3                                       <NA>                        <NA>
# 4  Illinois J. Math. 52 (2008) no.2, 681-689                        <NA>
#
#           report-no       categories  \
# 0  ANL-HEP-PR-07-12           hep-ph
# 1              <NA>    math.CO cs.CG
# 2              <NA>   physics.gen-ph
# 3              <NA>          math.CO
# 4              <NA>  math.CA math.FA
#
#                                              license  \
# 0                                               None
# 1  http://arxiv.org/licenses/nonexclusive-distrib...
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                             abstract  \
# 0    A fully differential calculation in perturba...
# 1    We describe a new algorithm, the $(k,\ell)$-...
# 2    The evolution of Earth-Moon system is descri...
# 3    We show that a determinant of Stirling cycle...
# 4    In this paper we show how to compute the $\L...
#
#                                             versions update_date  \
# 0  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2008-11-26
# 1  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2008-12-13
# 2  [{'version': 'v1', 'created': 'Sun, 1 Apr 2007...  2008-01-13
# 3  [{'version': 'v1', 'created': 'Sat, 31 Mar 200...  2007-05-23
# 4  [{'version': 'v1', 'created': 'Mon, 2 Apr 2007...  2013-10-15
#
#                                       authors_parsed
# 0  [['Balázs', 'C.', ''], ['Berger', 'E. L.', '']...
# 1  [['Streinu', 'Ileana', ''], ['Theran', 'Louis'...
# 2                           [['Pan', 'Hongjun', '']]
# 3                          [['Callan', 'David', '']]
# 4  [['Abu-Shammala', 'Wael', ''], ['Torchinsky', ...
# Dask DataFrame Structure:
#                    id submitter authors   title comments journal-ref     doi report-no categories license abstract versions update_date authors_parsed
# npartitions=1
#                string    string  string  string   string      string  string    string     string  string   string   string      string         string
#                   ...       ...     ...     ...      ...         ...     ...       ...        ...     ...      ...      ...         ...            ...
# Dask Name: to_pyarrow_string, 7934 graph layers

# %% [markdown]
# **Shrinking the arXiv dataset**
# First we drop all entries without a doi since we cannot merge them with the citation data.
#
# Then, we drop the following attributes:
# - `id`: We do not need the id since we have the doi
# - `versions`: We do not need the version since the version number has no meaning for new publications
# - `license`: The license should have no impact on the content of the paper
# - `report-no`: The report number should have no impact on the content of the paper
# - `submitter`: Submitter is not relevant to the content of the paper

# %%
# Remove entries without DOI
arxiv_raw = arxiv_raw.dropna(subset=["doi"])

# Drop attributes
arxiv_raw = arxiv_raw.drop(["versions", "license", "report-no", "id", "submitter"], axis=1)

arxiv_raw = arxiv_raw.set_index("doi")
arxiv_raw.to_parquet("dataset/arxiv_raw.parquet")

# %%
arxiv_raw.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/tillgrutschus/Library/CloudStorage/OneDrive-Personal/Documents/Arbeit und Beruf/Uppsala/Data Mining/uu-data-mining-project/dataset_merge.ipynb Cell 10 line 1
# ----> <a href='vscode-notebook-cell:/Users/tillgrutschus/Library/CloudStorage/OneDrive-Personal/Documents/Arbeit%20und%20Beruf/Uppsala/Data%20Mining/uu-data-mining-project/dataset_merge.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> arxiv_raw.head()
#
# File /opt/homebrew/anaconda3/envs/uu-data-mining/lib/python3.11/site-packages/dask/dataframe/core.py:1437, in _Frame.head(self, n, npartitions, compute)
#    1435 # No need to warn if we're already looking at all partitions
#    1436 safe = npartitions != self.npartitions
# -> 1437 return self._head(n=n, npartitions=npartitions, compute=compute, safe=safe)
#
# File /opt/homebrew/anaconda3/envs/uu-data-mining/lib/python3.11/site-packages/dask/dataframe/core.py:1471, in _Frame._head(self, n, npartitions, compute, safe)
#    1466 result = new_dd_object(
#    1467     graph, name, self._meta, [self.divisions[0], self.divisions[npartitions]]
#    1468 )
#    1470 if compute:
# -> 1471     result = result.compute()
#    1472 return result
#
# File /opt/homebrew/anaconda3/envs/uu-data-mining/lib/python3.11/site-packages/dask/base.py:342, in DaskMethodsMixin.compute(self, **kwargs)
#     318 def compute(self, **kwargs):
#     319     """Compute this dask collection
#     320
#     321     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     340     dask.compute
#     341     """
# --> 342     (result,) = compute(self, traverse=False, **kwargs)
#     343     return result
#
# File /opt/homebrew/anaconda3/envs/uu-data-mining/lib/python3.11/site-packages/dask/base.py:628, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     625     postcomputes.append(x.__dask_postcompute__())
#     627 with shorten_traceback():
# --> 628     results = schedule(dsk, keys, **kwargs)
#     630 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File /opt/homebrew/anaconda3/envs/uu-data-mining/lib/python3.11/queue.py:171, in Queue.get(self, block, timeout)
#     169 elif timeout is None:
#     170     while not self._qsize():
# --> 171         self.not_empty.wait()
#     172 elif timeout < 0:
#     173     raise ValueError("'timeout' must be a non-negative number")
#
# File /opt/homebrew/anaconda3/envs/uu-data-mining/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Loading and cleaning the citation dataset

# %% [markdown]
# #### Loading from parquet

# %%
citation_raw = dd.read_parquet('dataset/citation_raw.parquet')
citation_raw.head()
# Out:
#                                citation_count
# doi
# 10.10.18045/zbefri.2015.2.207               1
# 10.1000/182                                 3
# 10.1000/287                                 1
# 10.1000/res#test                            1
# 10.1001                                     6

# %% [markdown]
# #### Reloading dataset from scratch

# %%
CITATION_RAW_PATH = Path("dataset/coci-citation-count-2023-01-05.csv")
citation_raw = dd.read_csv(CITATION_RAW_PATH, blocksize=1e6)
citation_raw = citation_raw.rename(columns={"id": "doi"})
citation_raw = citation_raw.set_index("doi")
citation_raw.to_parquet("dataset/citation_raw.parquet")

# %%
citation_raw.head()
# Out:
#                                citation_count
# doi
# 10.10.18045/zbefri.2015.2.207               1
# 10.1000/182                                 3
# 10.1000/287                                 1
# 10.1000/res#test                            1
# 10.1001                                     6

# %% [markdown]
# ### Joining the two datasets

# %% [markdown]
# #### Loading from parquet

# %%
dataset_raw = dd.read_parquet('dataset/dataset_raw.parquet')
dataset_raw.head()
# Out:
#                                                                         authors  \
# doi
# 10.1002/adfm.202001307        Qinghua Zhao, Wanqi Jie, Tao Wang, Andres Cast...
# 10.1002/cphc.200900857        Haifeng Ma, Thomas Brugger, Simon Berner, Yun ...
# 10.1002/prop.200710532                         Milovan Vasilic, Marko Vojinovic
# 10.1007/978-3-030-30493-5_44        Itay Mosafi, Eli David, Nathan S. Netanyahu
# 10.1007/lrr-2015-1            Vitor Cardoso, Leonardo Gualtieri, Carlos Herd...
#
#                                                                           title  \
# doi
# 10.1002/adfm.202001307        InSe Schottky diodes based on van der Waals co...
# 10.1002/cphc.200900857          Boron Nitride Nanomesh: A template for Nano-ice
# 10.1002/prop.200710532        Interaction of the Particle with the String in...
# 10.1007/978-3-030-30493-5_44  DeepMimic: Mentor-Student Unlabeled Data Based...
# 10.1007/lrr-2015-1            Exploring New Physics Frontiers Through Numeri...
#
#                                                                        comments  \
# doi
# 10.1002/adfm.202001307        25 pages, 13 figures, Main text and Supporting...
# 10.1002/cphc.200900857                                                4 figures
# 10.1002/prop.200710532            Proceedings of the BW2007 conference, 5 pages
# 10.1007/978-3-030-30493-5_44                                               <NA>
# 10.1007/lrr-2015-1            156 pages, 21 figures. Published in Living Rev...
#
#                                                                     journal-ref  \
# doi
# 10.1002/adfm.202001307        Advanced Functional Materials, 30, 2001307 (2020)
# 10.1002/cphc.200900857                               ChemPhysChem 2010, 11, 399
# 10.1002/prop.200710532                                 Fortsch.Phys.56:542,2008
# 10.1007/978-3-030-30493-5_44  International Conference on Artificial Neural ...
# 10.1007/lrr-2015-1                                                         <NA>
#
#                                                        categories  \
# doi
# 10.1002/adfm.202001307        cond-mat.mes-hall cond-mat.mtrl-sci
# 10.1002/cphc.200900857        cond-mat.mtrl-sci cond-mat.mes-hall
# 10.1002/prop.200710532                               gr-qc hep-th
# 10.1007/978-3-030-30493-5_44                  cs.LG cs.NE stat.ML
# 10.1007/lrr-2015-1                gr-qc astro-ph.HE hep-ph hep-th
#
#                                                                        abstract  \
# doi
# 10.1002/adfm.202001307          Two-dimensional semiconductors are excellent...
# 10.1002/cphc.200900857          Using variable temperature scanning tunnelin...
# 10.1002/prop.200710532          Within the framework of generalized Papapetr...
# 10.1007/978-3-030-30493-5_44    In this paper, we present a deep neural netw...
# 10.1007/lrr-2015-1              The demand to obtain answers to highly compl...
#
#                              update_date  \
# doi
# 10.1002/adfm.202001307        2020-07-30
# 10.1002/cphc.200900857        2010-02-04
# 10.1002/prop.200710532        2015-05-20
# 10.1007/978-3-030-30493-5_44  2019-12-03
# 10.1007/lrr-2015-1            2015-11-11
#
#                                                                  authors_parsed  \
# doi
# 10.1002/adfm.202001307        [['Zhao', 'Qinghua', ''], ['Jie', 'Wanqi', '']...
# 10.1002/cphc.200900857        [['Ma', 'Haifeng', ''], ['Brugger', 'Thomas', ...
# 10.1002/prop.200710532        [['Vasilic', 'Milovan', ''], ['Vojinovic', 'Ma...
# 10.1007/978-3-030-30493-5_44  [['Mosafi', 'Itay', ''], ['David', 'Eli', ''],...
# 10.1007/lrr-2015-1            [['Cardoso', 'Vitor', ''], ['Gualtieri', 'Leon...
#
#                               citation_count
# doi
# 10.1002/adfm.202001307                    33
# 10.1002/cphc.200900857                    33
# 10.1002/prop.200710532                     1
# 10.1007/978-3-030-30493-5_44               0
# 10.1007/lrr-2015-1                        55

# %%
display(dataset_raw.shape[0].compute())
# Out:
# 573904

# %% [markdown]
# #### Reloading from scratch

# %%
display(citation_raw.shape[0].compute())
display(arxiv_raw.shape[0].compute())
# Out:
# 77045952
# 1142334

# %%
dataset_raw = arxiv_raw.join(citation_raw, how="inner")

# %%
# Save the final dataset
dataset_raw.to_parquet("dataset/dataset_raw.parquet")
